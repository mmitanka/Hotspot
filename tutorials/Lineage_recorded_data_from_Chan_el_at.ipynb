# %% [markdown]
# # Lineage-recorded data from Chan et al, (Nature 2019)
#
# This tutorial uses data from:
#
# _Molecular recording of mammalian embryogenesis_
#
#   - Chan et al (Nature 2019)
#   - [https://doi.org/10.1038/s41586-019-1184-5](https://doi.org/10.1038/s41586-019-1184-5)
#
#
# For this demo, you need the expression data (count matrix) for Embryo3 which can be found in the
# NCBI GEO database under accession [GSM3302829](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM3302829)
#
# Specifically these three files:
#
# - GSM3302829_embryo3_SeuratBarcodes.tsv.gz
# - GSM3302829_embryo3_SeuratGenes.tsv.gz
# - GSM3302829_embryo3_SeuratNorm.mtx.gz
#
# The cell-type kernels (for interpreting lineage groups) are located at [GSE122187](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE122187)
#
# - GSE122187_CellStateKernels.xls.gz
#
# Additionally, a reconstructed lineage tree is provided with this notebook (same directory) as made by [Cassiopeia](https://github.com/YosefLab/Cassiopeia)
#
# - 0726_E2-2_tree_greedy_priors.processed.txt

# %% [markdown]
# ## Covered Here
#
# - Data preprocessing and filtering
# - Computing Autocorrelation in Hotspot to identify lineage-related genes
# - Computing local correlations between lineage genes to identify heritable modules
# - Plotting modules, correlations, and module scores

# %%
import sys

# !pip install --upgrade numba
# !pip install hotspotsc
# !pip install scanpy
# !pip install mplscience
# !pip install ete3
# !pip3 install --upgrade xlrd==1.2.0
# Out:
# Requirement already satisfied: numba in /opt/conda/lib/python3.9/site-packages (0.54.0)
# Collecting numba
#   Downloading numba-0.57.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 31.7 MB/s eta 0:00:01
# Collecting numpy<1.25,>=1.21
#   Downloading numpy-1.24.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 98.0 MB/s eta 0:00:01
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1rc1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      |████████████████████████████████| 42.1 MB 114.2 MB/s eta 0:00:01
# Installing collected packages: numpy, llvmlite, numba
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.37.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting hotspotsc
#   Downloading hotspotsc-1.1.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (1.3.3)
# Requirement already satisfied: numpy>=1.16.4 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (1.24.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (0.12.2)
# Requirement already satisfied: scikit-learn>=0.21.2 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (0.24.2)
# Requirement already satisfied: scipy>=1.2.1 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (1.7.1)
# Collecting sphinx>=4.1
#   Downloading sphinx-7.0.1-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 50.9 MB/s eta 0:00:01
# Requirement already satisfied: numba>=0.43.1 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (0.54.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (3.4.3)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 127.0 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.32.2 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (4.62.2)
# Requirement already satisfied: seaborn>=0.9.0 in /opt/conda/lib/python3.9/site-packages (from hotspotsc) (0.11.2)
# Collecting anndata>=0.7
#   Downloading anndata-0.9.1-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 117.6 MB/s eta 0:00:01
# Requirement already satisfied: h5py>=3 in /opt/conda/lib/python3.9/site-packages (from anndata>=0.7->hotspotsc) (3.4.0)
# Collecting natsort
#   Downloading natsort-8.3.1-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=20 in /opt/conda/lib/python3.9/site-packages (from anndata>=0.7->hotspotsc) (21.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0.0->hotspotsc) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0.0->hotspotsc) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0.0->hotspotsc) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0.0->hotspotsc) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0.0->hotspotsc) (1.3.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.0.0->hotspotsc) (1.16.0)
# Collecting numpy>=1.16.4
#   Downloading numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 124.8 MB/s eta 0:00:01
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /opt/conda/lib/python3.9/site-packages (from numba>=0.43.1->hotspotsc) (0.37.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from numba>=0.43.1->hotspotsc) (58.0.4)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.24.0->hotspotsc) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.9/site-packages (from pynndescent>=0.5->hotspotsc) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn>=0.21.2->hotspotsc) (2.2.0)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.1-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 18.8 MB/s  eta 0:00:01
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 5.7 MB/s s eta 0:00:01
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.4-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 130.3 MB/s eta 0:00:01
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 18.5 MB/s  eta 0:00:01
# Collecting Pygments>=2.13
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 100.5 MB/s eta 0:00:01
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 3.0 MB/s s eta 0:00:01
# Requirement already satisfied: importlib-metadata>=4.8 in /opt/conda/lib/python3.9/site-packages (from sphinx>=4.1->hotspotsc) (4.8.1)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.13-py3-none-any.whl (13 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 7.4 MB/s s eta 0:00:01
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.9/site-packages (from sphinx>=4.1->hotspotsc) (2.26.0)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.9/site-packages (from sphinx>=4.1->hotspotsc) (3.0.1)
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting docutils<0.21,>=0.18.1
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      |████████████████████████████████| 572 kB 138.6 MB/s eta 0:00:01
# Requirement already satisfied: babel>=2.9 in /opt/conda/lib/python3.9/site-packages (from sphinx>=4.1->hotspotsc) (2.9.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata>=4.8->sphinx>=4.1->hotspotsc) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from Jinja2>=3.0->sphinx>=4.1->hotspotsc) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.0->sphinx>=4.1->hotspotsc) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.0->sphinx>=4.1->hotspotsc) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.0->sphinx>=4.1->hotspotsc) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.0->sphinx>=4.1->hotspotsc) (3.1)
# Requirement already satisfied: patsy>=0.5 in /opt/conda/lib/python3.9/site-packages (from statsmodels>=0.9.0->hotspotsc) (0.5.1)
# Building wheels for collected packages: pynndescent
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55639 sha256=fad5e19fa1ccb2a413510348cab204ece49e7501cd5e09a981b3a4480ace35c5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/12/f9/4d/ec5ad1c823c710fcc4473669fdcffc8891f4bc398c841af22e
# Successfully built pynndescent
# Installing collected packages: numpy, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, Pygments, natsort, imagesize, docutils, alabaster, sphinx, pynndescent, anndata, hotspotsc
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
# Successfully installed Pygments-2.15.1 alabaster-0.7.13 anndata-0.9.1 docutils-0.20.1 hotspotsc-1.1.1 imagesize-1.4.1 natsort-8.3.1 numpy-1.20.3 pynndescent-0.5.10 snowballstemmer-2.2.0 sphinx-7.0.1 sphinxcontrib-applehelp-1.0.4 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5
# Collecting scanpy
#   Downloading scanpy-1.9.3-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 25.9 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.9/site-packages (from scanpy) (1.7.1)
# Requirement already satisfied: natsort in /opt/conda/lib/python3.9/site-packages (from scanpy) (8.3.1)
# Requirement already satisfied: patsy in /opt/conda/lib/python3.9/site-packages (from scanpy) (0.5.1)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from scanpy) (1.20.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from scanpy) (4.62.2)
# Requirement already satisfied: h5py>=3 in /opt/conda/lib/python3.9/site-packages (from scanpy) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from scanpy) (21.0)
# Requirement already satisfied: numba>=0.41.0 in /opt/conda/lib/python3.9/site-packages (from scanpy) (0.54.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.9/site-packages (from scanpy) (0.11.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from scanpy) (1.0.1)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /opt/conda/lib/python3.9/site-packages (from scanpy) (0.12.2)
# Requirement already satisfied: anndata>=0.7.4 in /opt/conda/lib/python3.9/site-packages (from scanpy) (0.9.1)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 10.3 MB/s  eta 0:00:01
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
# Requirement already satisfied: matplotlib>=3.4 in /opt/conda/lib/python3.9/site-packages (from scanpy) (3.4.3)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.9/site-packages (from scanpy) (0.24.2)
# Requirement already satisfied: networkx>=2.3 in /opt/conda/lib/python3.9/site-packages (from scanpy) (2.5)
# Requirement already satisfied: pandas>=1.0 in /opt/conda/lib/python3.9/site-packages (from scanpy) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (8.3.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.4->scanpy) (1.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.9/site-packages (from networkx>=2.3->scanpy) (5.1.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /opt/conda/lib/python3.9/site-packages (from numba>=0.41.0->scanpy) (0.37.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from numba>=0.41.0->scanpy) (58.0.4)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0->scanpy) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn>=0.22->scanpy) (2.2.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.9/site-packages (from umap-learn>=0.3.10->scanpy) (0.5.10)
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 4.4 MB/s s eta 0:00:01
# Building wheels for collected packages: umap-learn, session-info
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=149c0f600067857a584efb8c8bbaff4e5a0fef0c349bee1ec287531a563d19e5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8045 sha256=c192bc82ae833248902dae7b2fac0954beaf676212cde24ad5cebd2cc76bc4a9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d4/fc/2e/00ca60bac7954b84907efd41baa9b4853500eaeec4228410c6
# Successfully built umap-learn session-info
# Installing collected packages: stdlib-list, umap-learn, session-info, scanpy
# Successfully installed scanpy-1.9.3 session-info-1.0.0 stdlib-list-0.8.0 umap-learn-0.5.3
# Collecting mplscience
#   Downloading mplscience-0.0.7-py3-none-any.whl (4.8 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from mplscience) (3.4.3)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.9/site-packages (from mplscience) (0.11.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->mplscience) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->mplscience) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->mplscience) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->mplscience) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.9/site-packages (from matplotlib->mplscience) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->mplscience) (8.3.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->mplscience) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in /opt/conda/lib/python3.9/site-packages (from seaborn->mplscience) (1.3.3)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.9/site-packages (from seaborn->mplscience) (1.7.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.23->seaborn->mplscience) (2021.1)
# Installing collected packages: mplscience
# Successfully installed mplscience-0.0.7
# Collecting ete3
#   Downloading ete3-3.1.3.tar.gz (4.8 MB)
#      |████████████████████████████████| 4.8 MB 30.9 MB/s eta 0:00:01
# Building wheels for collected packages: ete3
#   Building wheel for ete3 (setup.py) ... done
#   Created wheel for ete3: filename=ete3-3.1.3-py3-none-any.whl size=2273789 sha256=2607e6b62b4bac8b3cfb9bf563afdd373a1205b966e05b0574fa105133bb7757
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ad/2e/cc/edcca721b423e1604c84f480a1e8e0547a223bfc068d373259
# Successfully built ete3
# Installing collected packages: ete3
# Successfully installed ete3-3.1.3
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 21.3 MB/s eta 0:00:01
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
# Successfully installed xlrd-1.2.0

# %%
import warnings; warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import hotspot
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns
import mplscience

from scipy.io import mmread
from scipy.sparse import csr_matrix

import scanpy as sc

# %%
counts_raw = mmread("../project-files/Lineage_recorded_data_from_Chan_et_al/GSM3302829_embryo3_SeuratNorm.mtx.gz")
counts_raw = csr_matrix(counts_raw)
barcodes = pd.read_table("../project-files/Lineage_recorded_data_from_Chan_et_al/GSM3302829_embryo3_SeuratBarcodes.tsv.gz", header=None)[0]
barcodes = [x+'-1' for x in barcodes] # to match the newick file
genes = pd.read_table("../project-files/Lineage_recorded_data_from_Chan_et_al/GSM3302829_embryo3_SeuratGenes.tsv.gz", header=None)[0]

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.9/site-packages (from gdown) (2.26.0)
# Collecting filelock
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from gdown) (4.62.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.9/site-packages (from gdown) (4.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests[socks]->gdown) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests[socks]->gdown) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests[socks]->gdown) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests[socks]->gdown) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: filelock, gdown
# Successfully installed filelock-3.12.2 gdown-4.7.1

# %%
# %%capture
import gdown
url = "https://drive.google.com/uc?id=1FlrryhNv9Khwo_BstUTPCBOVaMgZLZ9N"
output = 'tree.txt'
gdown.download(url, output, quiet=False)

# %%
# Load the tree and enumerate the leaves
from ete3 import Tree
tree = Tree("tree.txt", format=1)
leaves = set()
for tn in tree.traverse('postorder'):
    if tn.is_leaf():
        leaves.add(tn.name)
len(leaves)
# Out:
# 1756

# %%
# Subset the count matrix to only the cells where the lineage was recoverable
is_valid = [x in leaves for x in barcodes]
is_valid_indices = np.nonzero(is_valid)[0]
valid_barcodes = [barcodes[i] for i in is_valid_indices]

# %%
adata = sc.AnnData(counts_raw.transpose())
adata.obs_names = barcodes
adata.var_names = genes

adata = adata[valid_barcodes]
sc.pp.filter_genes(adata, min_cells=10)

# %% [markdown]
# ## Creating the Hotspot object
#
# To start an analysis, first create the hotspot object
# When creating the object, you need to specify:
#
# - The gene counts matrix
# - Which background model to use
# - The latent space we are using to compute our cell metric
#     - Here we use the inferred cell tree
# - The per-cell scaling factor
#     - Here we use the number of umi per barcode
#
# In this case, only the *log-normalized counts* are made available.  In the Hotspot publication, we used the raw counts and the negative binomial ('danb') model.  However, to make this example easier to run, here we just supply the log-normalized counts and select the 'normal' model.
#
# Once the object is created, the neighborhood is then computed with `create_knn_graph`
#
# The two options that are specificied are `n_neighbors` which determines the size of the neighborhood, and `weighted_graph`.
#
# Here we set `weighted_graph=False` to just use binary, 0-1 weights (only binary weights are supported when using a lineage tree) and `n_neighbors=30` to create a local neighborhood size of the nearest 30 cells.  Larger neighborhood sizes can result in more robust detection of correlations and autocorrelations at a cost of missing more fine-grained, smaller-scale patterns.

# %%
# Create the Hotspot object and the neighborhood graph

hs = hotspot.Hotspot(adata, model='normal', tree=tree)

hs.create_knn_graph(
    weighted_graph=False, n_neighbors=30,
)
# Out:
# 100%|██████████| 1756/1756 [00:10<00:00, 159.84it/s]

# %% [markdown]
# ## Determining genes with heritable variation
#
# Now we compute autocorrelations for each gene, using the lineage metric, to determine which genes have the most heritable variation.

# %%
hs_results = hs.compute_autocorrelations(jobs=1)

hs_results.head(15)
# Out:
# 100%|██████████| 12440/12440 [00:06<00:00, 2072.76it/s]
#                  C          Z  Pval  FDR
# Gene
# Rhox9     0.391416  66.446015   0.0  0.0
# Gjb3      0.326593  58.855027   0.0  0.0
# Gm9       0.293843  51.361004   0.0  0.0
# Utf1      0.300955  50.754834   0.0  0.0
# Ldoc1     0.294314  50.709101   0.0  0.0
# Rhox6     0.268615  47.329648   0.0  0.0
# Pramef12  0.242848  44.918431   0.0  0.0
# Tfap2c    0.268835  43.744788   0.0  0.0
# S100g     0.227212  40.685998   0.0  0.0
# Apom      0.220112  39.937071   0.0  0.0
# Apoa1     0.217818  39.522119   0.0  0.0
# Rbp4      0.219662  39.344467   0.0  0.0
# Ascl2     0.221699  39.249587   0.0  0.0
# Ttr       0.213251  38.544657   0.0  0.0
# Rhox5     0.213615  38.057517   0.0  0.0

# %% [markdown]
# ## Grouping genes into lineage-based modules
#
# To get a better idea of what heritable expression patterns exist, it is helpful to group the genes into modules.
#
# Hotspot does this using the concept of "local correlations" - that is, <br>
# correlations that are computed between genes between cells in the same neighborhood.
#
# Here we avoid running the calculation for all Genes x Genes pairs and instead <br> only run this on genes that have significant lineage autocorrelation to begin with.
#
# The method `compute_local_correlations` returns a Genes x Genes matrix of <br>
# Z-scores for the significance of the correlation between genes.  This object <br>
# is also retained in the `hs` object and is used in the subsequent steps.

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index[hs_results.FDR < 0.05]

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=2)
# Out:
# Computing pair-wise local correlation on 2120 features...
# 100%|██████████| 2120/2120 [00:00<00:00, 6768.68it/s]
# 100%|██████████| 2246140/2246140 [02:31<00:00, 14787.40it/s]

# %% [markdown]
# Now that pair-wise local correlations are calculated, we can group genes into modules.
#
# To do this, a convenience method is included `create_modules` which performs <br>
# agglomerative clustering with two caveats:
#
# - If the FDR-adjusted p-value of the correlation between two branches exceeds `fdr_threshold`, <br>
# then the branches are not merged.
# - If two branches are two be merged and they are both have at least `min_gene_threshold` genes, <br>
# then the branches are not merged.  Further genes that would join to the resulting merged module <br> (and are therefore ambiguous) either remain unassigned (if `core_only=True`) or are assigned to the module with the <br>
# smaller average correlations between genes, i.e. the least-dense module (if `core_only=False`)
#
# The output is a Series that maps gene to module number.  Unassigned genes are indicated with a module number of `-1`
#
# This method was used to preserved substructure (nested modules) while still giving the analyst <br>
# some control. However, since there are a lot of ways to do hierarchical clustering, you can also <br>
# manually cluster using the gene-distances in `hs.local_correlation_z`

# %%
modules = hs.create_modules(
    min_gene_threshold=50, core_only=True, fdr_threshold=0.05
)

modules.value_counts()
# Out:
#  1    770
# -1    535
#  3    483
#  2    202
#  4     72
#  5     58
# Name: Module, dtype: int64

# %% [markdown]
# ## Plotting module correlations
#
# A convenience method is supplied to plot the results of `hs.create_modules`

# %%
hs.plot_local_correlations()

# %% [markdown]
# To explore individual genes, we can look at the genes with the top *autocorrelation* <br>
# in a given module as these are likely the most informative.

# %%
# Show the top genes for a module

module = 3

results = hs.results.join(hs.modules)
results = results.loc[results.Module == module]
results.sort_values('Z', ascending=False).head(10)
# Out:
#                       C          Z           Pval            FDR  Module
# Gene
# Marcksl1       0.143827  26.523568  2.592121e-155  5.971480e-153     3.0
# Tuba1a         0.135315  24.772273  8.922004e-136  1.761742e-133     3.0
# Tmsb10         0.117421  21.373499  1.178913e-101   1.788497e-99     3.0
# Ybx1           0.121662  20.788592   2.744892e-96   3.794051e-94     3.0
# H3f3a          0.115818  20.501410   1.045730e-93   1.383924e-91     3.0
# Fabp5          0.110815  19.893154   2.332368e-88   2.930774e-86     3.0
# Ifitm2         0.105812  19.817143   1.058992e-87   1.317386e-85     3.0
# 2810417H13Rik  0.109985  19.796747   1.587748e-87   1.955603e-85     3.0
# Mest           0.100997  18.993365   9.676144e-81   1.146393e-78     3.0
# Stmn1          0.107345  18.933678   3.010401e-80   3.532961e-78     3.0

# %% [markdown]
# To get an idea of what lineage patterns the module is referencing, we can plot the <br>
# kernel values

# %%
# Load Kernel values
import gzip
with gzip.open("../project-files/Lineage_recorded_data_from_Chan_et_al/GSE122187_CellStateKernels.xls.gz") as fin:
    kernels = pd.read_excel(fin, skiprows=1).set_index('Gene')

kernels = kernels.loc[
    :, kernels.columns.sort_values()
]

kernel_name_map = {
    0: "trophoblast stem cells",
    1: "neural ectoderm anterior",
    2: "primitive streak late",
    3: "anterior primitive streak",
    4: "primitive/definitive endoderm",
    5: "allantois",
    6: "secondary heart field/splanchnic lateral plate",
    7: "gut endoderm",
    8: "ectoderm early 1",
    9: "primitive blood early",
    10: "preplacodal ectoderm",
    11: "neural ectoderm posterior",
    12: "posterior lateral plate mesoderm",
    13: "hematopoietic/endothelial progenitors",
    14: "parietal endoderm",
    15: "amnion mesoderm early",
    16: "surface ectoderm",
    17: "epiblast",
    18: "somites",
    19: "ectoderm early 2",
    20: "splanchnic lateral plate/anterior paraxial mesoderm",
    21: "primitive heart tube",
    22: "primitive blood late",
    23: "notochord",
    24: "fore/midbrain",
    25: "distal extraembryonic ectoderm",
    26: "neuromesodermal progenitor early",
    27: "primordial germ cells",
    28: "differentiated trophoblasts",
    29: "visceral endoderm early",
    30: "presomitic mesoderm",
    31: "neuromesodermal progenitor late",
    32: "angioblasts",
    33: "neural crest",
    34: "pharyngeal arch mesoderm",
    35: "similar to neural crest",
    36: "primitive blood progenitors",
    37: "primitive streak early",
    38: "node",
    39: "future spinal cord",
    40: "visceral endoderm late",
    41: "amnion mesoderm late",
}

kernel_name_map = {k: v.capitalize() for k, v in kernel_name_map.items()}

kernels.columns = [kernel_name_map[x] for x in kernels.columns]

# Standardize each gene
kernels_z = kernels \
    .subtract(kernels.mean(axis=1), axis=0) \
    .divide(kernels.std(axis=1), axis=0)


# Plot the kernel values for the genes in each module
mods = hs.modules.unique()
mods = [x for x in mods if x != -1 and not np.isnan(x)]
mods = sorted(mods)

sizes = [(hs.modules == x).sum() for x in mods]
sizes = [np.log10(x) for x in sizes]

fig, axs = plt.subplots(
    len(mods), 1, gridspec_kw=dict(height_ratios=sizes, right=.8),
    figsize=(9, 12.5)
)

cbax = fig.add_axes([.85, .15, .015, .1])

for ax, mod in zip(axs.ravel(), mods):

    plt.sca(ax)
    mod_genes = hs.modules.index[hs.modules == mod]
    mod_genes = pd.Index(mod_genes) & kernels.index

    last_plot = mod == max(mods)

    if last_plot:
        cbar=True
        cbar_ax=cbax
    else:
        cbar=False
        cbar_ax=None

    sns.heatmap(kernels_z.loc[mod_genes], vmin=-2, vmax=2,
                cmap="RdBu_r", ax=ax, xticklabels=True, rasterized=True,
                cbar=cbar, cbar_ax=cbar_ax)
    plt.ylabel(int(mod))

    plt.yticks([])

    if last_plot:
        ax.tick_params(labelsize=9)
    else:
        plt.xticks([])

plt.tight_layout()

# %% [markdown]
# ## Summary Module Scores
#
# To aid in the recognition of the general behavior of a module, Hotspot can compute <br>
# aggregate module scores.

# %%
module_scores = hs.calculate_module_scores()

module_scores.head()
# Out:
# Computing scores for 5 modules...
# 100%|██████████| 5/5 [00:01<00:00,  4.56it/s]
#                            1         2         3         4         5
# AAACCTGAGAATAGGG-1 -6.483104 -0.177020  5.628530 -1.794523  1.399653
# AAACCTGAGACCCACC-1 -7.692313 -0.342778  8.527888 -1.466340  1.514233
# AAACCTGAGCAGCGTA-1  3.728869 -1.035047 -3.198861 -0.055501 -0.555942
# AAACCTGAGCCCAATT-1  3.062484 -0.509458 -2.078423 -1.030088 -0.515304
# AAACCTGAGTACGACG-1  5.747993 -0.450279 -2.864529 -1.456273 -0.354508

# %% [markdown]
# Here we can visualize these module scores by plotting them over a UMAP of the cells
#
# First we'll compute the UMAP

# %%
adata.raw = adata

# %%
sc.pp.scale(adata)
sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# Next, let's use the Kernels to assign every cell to its closest profile

# %%
from scipy.spatial.distance import cdist

common = adata.var_names & kernels.index
dd = cdist(adata.raw[:, common].X.A, kernels.loc[common].T, metric='cosine')
dd = pd.DataFrame(dd, index=adata.obs_names, columns=kernels.columns)
assignment = dd.idxmin(axis=1).loc[adata.obs_names]
